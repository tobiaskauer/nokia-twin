# %%
import pandas as pd
import sqlalchemy

# %%
#example csv at https://docs.google.com/spreadsheets/d/1QhjE27TJ-AiFbC4pea39ajy_l-iAAVDUKoBIDMpoMFE/edit?usp=sharing
# table = "global"
# data = pd.read_csv('global_data.csv')
# display = pd.read_csv('global_display.csv')
# events = pd.read_csv('global_events.csv')

# table = "example"
# data = pd.read_csv('example_data.csv')
# display = pd.read_csv('example_display.csv')
# events = pd.read_csv('example_events.csv')

table = "medical"
data = pd.read_csv('medical_data.csv')
display = pd.read_csv('medical_display.csv')
events = pd.read_csv('medical_events.csv')

#parse a given date to datetime
data['date'] = pd.to_datetime(data['date'], infer_datetime_format=True) 
events['date'] = pd.to_datetime(events['date'], infer_datetime_format=True) 


#ignore everthing that's not a filter, metric or date or weight
filters = [x for x in data.columns if x.startswith('filter_')] 
metrics = [x for x in data.columns if x.startswith('metric_')]
filtered_data = data[['date'] + ['weight'] + filters + metrics ]

# %%
#setup connection
host = "goodcitylife.org"
user = "dquercia_twin"
password = "&Ta15WOr1ZX@"
database = "dquercia_nokiatwin"
data_table = table+"_data"
display_table= table+"_display"
events_table= table+"_events"

engine = sqlalchemy.create_engine('mysql+mysqlconnector://'+user+':'+password+'@'+host+'/'+database)

#write new database to db
#OVERWRITES EXISTING TABLES

filtered_data.to_sql(con=engine, name=data_table, if_exists='replace',dtype={"date": sqlalchemy.types.DateTime()})
events.to_sql(con=engine, name=events_table, if_exists='replace',dtype={"date": sqlalchemy.types.DateTime()})
display.to_sql(con=engine,name=display_table,if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/mysql/connector/network.py in send_plain(self, buf, packet_number, compressed_packet_number)
#     139                 else:
# --> 140                     self.sock.sendall(packet)
#     141             except IOError as err:
#
# BrokenPipeError: [Errno 32] Broken pipe
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_executemany(self, cursor, statement, parameters, context)
#     589     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 590         cursor.executemany(statement, parameters)
#     591
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/mysql/connector/cursor.py in executemany(self, operation, seq_params)
#     653             if stmt is not None:
# --> 654                 return self.execute(stmt)
#     655
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/mysql/connector/cursor.py in execute(self, operation, params, multi)
#     550             try:
# --> 551                 self._handle_result(self._connection.cmd_query(stmt))
#     552             except errors.InterfaceError:
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/mysql/connector/connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     489             query = query.encode('utf-8')
# --> 490         result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     491
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/mysql/connector/connection.py in _send_cmd(self, command, argument, packet_number, packet, expect_response, compressed_packet_number)
#     258         try:
# --> 259             self._socket.send(
#     260                 self._protocol.make_command(command, packet or argument),
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/mysql/connector/network.py in send_plain(self, buf, packet_number, compressed_packet_number)
#     141             except IOError as err:
# --> 142                 raise errors.OperationalError(
#     143                     errno=2055, values=(self.get_address(), _strioerror(err)))
#
# OperationalError: 2055: Lost connection to MySQL server at 'goodcitylife.org:3306', system error: 32 Broken pipe
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-3-6d38f58b0daf> in <module>
#      13 #OVERWRITES EXISTING TABLES
#      14
# ---> 15 filtered_data.to_sql(con=engine, name=data_table, if_exists='replace',dtype={"date": sqlalchemy.types.DateTime()})
#      16 events.to_sql(con=engine, name=events_table, if_exists='replace',dtype={"date": sqlalchemy.types.DateTime()})
#      17 display.to_sql(con=engine,name=display_table,if_exists='replace')
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1122             )
#    1123
# -> 1124         ret = self._execute_context(
#    1125             dialect,
#    1126             dialect.execution_ctx_cls._init_compiled,
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1254                             break
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#    1258                     )
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_executemany(self, cursor, statement, parameters, context)
#     588
#     589     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 590         cursor.executemany(statement, parameters)
#     591
#     592     def do_execute(self, cursor, statement, parameters, context=None):
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/mysql/connector/cursor.py in executemany(self, operation, seq_params)
#     652             stmt = self._batch_insert(operation, seq_params)
#     653             if stmt is not None:
# --> 654                 return self.execute(stmt)
#     655
#     656         rowcnt = 0
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/mysql/connector/cursor.py in execute(self, operation, params, multi)
#     549         else:
#     550             try:
# --> 551                 self._handle_result(self._connection.cmd_query(stmt))
#     552             except errors.InterfaceError:
#     553                 if self._connection._have_next_result:  # pylint: disable=W0212
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/mysql/connector/connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     488         if not isinstance(query, bytes):
#     489             query = query.encode('utf-8')
# --> 490         result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     491
#     492         if self._have_next_result:
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/mysql/connector/connection.py in _send_cmd(self, command, argument, packet_number, packet, expect_response, compressed_packet_number)
#     257
#     258         try:
# --> 259             self._socket.send(
#     260                 self._protocol.make_command(command, packet or argument),
#     261                 packet_number, compressed_packet_number)
#
# /opt/anaconda3/envs/ana/lib/python3.8/site-packages/mysql/connector/network.py in send_plain(self, buf, packet_number, compressed_packet_number)
#     140                     self.sock.sendall(packet)
#     141             except IOError as err:
# --> 142                 raise errors.OperationalError(
#     143                     errno=2055, values=(self.get_address(), _strioerror(err)))
#     144             except AttributeError:
#
# OperationalError: (mysql.connector.errors.OperationalError) 2055: Lost connection to MySQL server at 'goodcitylife.org:3306', system error: 32 Broken pipe
# [SQL: INSERT INTO medical_data (`index`, date, weight, filter_employee_title, filter_company, metric_sbs, metric_mental_health, metric_stress, metric_heart_disease, metric_ptsd, metric_tot_sym, metric_cli_basic, metric_back_problems, metric_cli_full) VALUES (%(index)s, %(date)s, %(weight)s, %(filter_employee_title)s, %(filter_company)s, %(metric_sbs)s, %(metric_mental_health)s, %(metric_stress)s, %(metric_heart_disease)s, %(metric_ptsd)s, %(metric_tot_sym)s, %(metric_cli_basic)s, %(metric_back_problems)s, %(metric_cli_full)s)]
# [parameters: ({'index': 0, 'date': datetime.datetime(2020, 5, 1, 0, 0), 'weight': 1.0, 'filter_employee_title': ' Customer Service Representative', 'filter_company': 'comerica', 'metric_sbs': 0.0, 'metric_mental_health': 0.0, 'metric_stress': 0.0, 'metric_heart_disease': 0.0, 'metric_ptsd': 0.0, 'metric_tot_sym': 0.0, 'metric_cli_basic': 0.0, 'metric_back_problems': 0.0, 'metric_cli_full': 0.0}, {'index': 1, 'date': datetime.datetime(2020, 5, 1, 0, 0), 'weight': 1.0, 'filter_employee_title': ' Analyst', 'filter_company': 'comerica', 'metric_sbs': 0.0, 'metric_mental_health': 0.0, 'metric_stress': 0.0, 'metric_heart_disease': 0.0, 'metric_ptsd': 0.0, 'metric_tot_sym': 0.0, 'metric_cli_basic': 0.0, 'metric_back_problems': 0.0, 'metric_cli_full': 0.0}, {'index': 2, 'date': datetime.datetime(2020, 5, 1, 0, 0), 'weight': 1.0, 'filter_employee_title': ' Retail Personal Banker', 'filter_company': 'comerica', 'metric_sbs': 0.0, 'metric_mental_health': 0.0, 'metric_stress': 0.0, 'metric_heart_disease': 0.0, 'metric_ptsd': 0.0, 'metric_tot_sym': 0.0, 'metric_cli_basic': 0.0, 'metric_back_problems': 0.0, 'metric_cli_full': 0.0}, {'index': 3, 'date': datetime.datetime(2020, 4, 1, 0, 0), 'weight': 1.0, 'filter_employee_title': ' Underwriter', 'filter_company': 'comerica', 'metric_sbs': 0.0, 'metric_mental_health': 0.0, 'metric_stress': 0.0, 'metric_heart_disease': 0.0, 'metric_ptsd': 0.0, 'metric_tot_sym': 0.0, 'metric_cli_basic': 0.0, 'metric_back_problems': 0.0, 'metric_cli_full': 0.0}, {'index': 4, 'date': datetime.datetime(2020, 3, 1, 0, 0), 'weight': 1.0, 'filter_employee_title': ' Customer Service Representative', 'filter_company': 'comerica', 'metric_sbs': 0.0, 'metric_mental_health': 0.0, 'metric_stress': 0.0, 'metric_heart_disease': 0.0, 'metric_ptsd': 0.0, 'metric_tot_sym': 0.0, 'metric_cli_basic': 0.0, 'metric_back_problems': 0.0, 'metric_cli_full': 0.0}, {'index': 5, 'date': datetime.datetime(2020, 3, 1, 0, 0), 'weight': 1.0, 'filter_employee_title': None, 'filter_company': 'comerica', 'metric_sbs': 0.0, 'metric_mental_health': 0.0, 'metric_stress': 0.0, 'metric_heart_disease': 0.0, 'metric_ptsd': 0.0, 'metric_tot_sym': 0.0, 'metric_cli_basic': 0.0, 'metric_back_problems': 0.0, 'metric_cli_full': 0.0}, {'index': 6, 'date': datetime.datetime(2020, 2, 1, 0, 0), 'weight': 1.0, 'filter_employee_title': ' Banking Center Manager', 'filter_company': 'comerica', 'metric_sbs': 0.0, 'metric_mental_health': 0.0, 'metric_stress': 0.0, 'metric_heart_disease': 0.0, 'metric_ptsd': 0.0, 'metric_tot_sym': 0.0, 'metric_cli_basic': 0.0, 'metric_back_problems': 0.0, 'metric_cli_full': 0.0}, {'index': 7, 'date': datetime.datetime(2020, 3, 1, 0, 0), 'weight': 1.0, 'filter_employee_title': ' Bank Teller', 'filter_company': 'comerica', 'metric_sbs': 0.0, 'metric_mental_health': 0.0, 'metric_stress': 0.0, 'metric_heart_disease': 0.0, 'metric_ptsd': 0.0, 'metric_tot_sym': 0.0, 'metric_cli_basic': 0.0, 'metric_back_problems': 0.0, 'metric_cli_full': 0.0}  ... displaying 10 of 646468 total bound parameter sets ...  {'index': 646466, 'date': datetime.datetime(2013, 3, 1, 0, 0), 'weight': 1.0, 'filter_employee_title': None, 'filter_company': 'equinix', 'metric_sbs': 0.0, 'metric_mental_health': 0.0, 'metric_stress': 0.0, 'metric_heart_disease': 0.0, 'metric_ptsd': 0.0, 'metric_tot_sym': 0.0, 'metric_cli_basic': 0.0, 'metric_back_problems': 0.0, 'metric_cli_full': 0.0}, {'index': 646467, 'date': datetime.datetime(2013, 1, 1, 0, 0), 'weight': 1.0, 'filter_employee_title': None, 'filter_company': 'equinix', 'metric_sbs': 0.0, 'metric_mental_health': 0.0, 'metric_stress': 0.0, 'metric_heart_disease': 0.0, 'metric_ptsd': 0.0, 'metric_tot_sym': 0.0, 'metric_cli_basic': 0.0, 'metric_back_problems': 0.0, 'metric_cli_full': 0.0})]
# (Background on this error at: http://sqlalche.me/e/13/e3q8)
